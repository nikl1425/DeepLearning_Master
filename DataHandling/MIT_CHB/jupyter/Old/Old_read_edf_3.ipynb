# %%
# What version of Python do you have?
import sys
import os
import tensorflow.keras
import pandas as pd
import sklearn as sk
import tensorflow as tf
import numpy as np
import re
import mne
import pathlib
import openpyxl
from datetime import datetime
import pytz
import random
import os
from skimage.restoration import (denoise_wavelet, estimate_sigma)
from pathlib import Path
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras import layers, models, Sequential
from matplotlib import pyplot as plt
pd.io.parquet.get_engine('auto').__class__
# %matplotlib inline

print(f"Tensor Flow Version: {tf.__version__}")
print(f"Keras Version: {tensorflow.keras.__version__}")
print()
print(f"Python {sys.version}")
print(f"Pandas {pd.__version__}")
print(f"Scikit-Learn {sk.__version__}")
gpu = len(tf.config.list_physical_devices('GPU'))>0
print("GPU is", "available" if gpu else "NOT AVAILABLE")
# Out:
# Tensor Flow Version: 2.7.0
# Keras Version: 2.7.0
#
# Python 3.9.7 (default, Sep 16 2021, 23:53:23)
# [Clang 12.0.0 ]
# Pandas 1.3.4
# Scikit-Learn 1.0.1
# GPU is available

# %% [markdown]
# Globals

# %%
cwd = os.getcwd()
FREQ = 256
database_path = 'Dataset/CHB-MIT/chb-mit-scalp-eeg-database-1.0.0/'
filtered_database_path = '../Dataset/CHB-MIT/Filtered-chb-mit/'
filted_db_parquet_path = "Dataset/CHB-MIT/dataframe-parquet"
save_csv_path = "../DataSet/CHB-MIT/filtered_df_csv"
edf_file_type = ".edf"
patient_one_path = 'chb04/'
summary_txt_file_type = "-summary.txt"
external_hardisk_drive_path = os.path.dirname('/Volumes/LaCie/Database/')
cwd
# Out:
# '/Users/niklashjort/Desktop/Notes/Speciale/projects/DataHandling/MIT_CHB'

# %% [markdown]
# Get file paths and info.txt

# %%
def get_all_patient_folder_names(database_path):
    folders = os.listdir(database_path)
    patient_folder_names = [(database_path + "/" + x) for x in folders if (x.find(".DS_Store") == -1)]
    return patient_folder_names

def get_all_file_names(directory):
    files = os.listdir(directory)
    edfFileNameList = [(directory + "/" + x) for x in files if (x.endswith(edf_file_type))]
    summary_info_file_name = [(directory + "/" + x) for x in files if (x.endswith(summary_txt_file_type))]
    return (summary_info_file_name[0], edfFileNameList)

# %% [markdown]
# Read EDF

# %%
def ReadEdfFile(FileName, print_reader_info = False):
    try:
        if(print_reader_info):
            data = mne.io.read_raw_edf(FileName)
            raw_data = data.get_data()
            converted_raw = pd.DataFrame(raw_data.transpose(), columns=data.ch_names)
            print(data.info)
            return converted_raw
        else:
            data = mne.io.read_raw_edf(FileName, verbose='error')
            raw_data = data.get_data()
            converted_raw = pd.DataFrame(raw_data.transpose(), columns=data.ch_names)
            return converted_raw
    except Exception as e:
        pass

# %%
x = mne.io.read_raw_edf(filtered_database_path + "chb01/chb01_06.edf")
y = ReadEdfFile(filtered_database_path + "chb10/chb10_12.edf", print_reader_info=True)
# Out:
# Extracting EDF parameters from ../Dataset/CHB-MIT/Filtered-chb-mit/chb01/chb01_06.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from ../Dataset/CHB-MIT/Filtered-chb-mit/chb10/chb10_12.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# <Info | 17 non-empty fields
#     bads : list | 0 items
#     buffer_size_sec : float | 1.0
#     ch_names : list | FP1-F7, F7-T7, T7-P7, P7-O1, FP1-F3, F3-C3, C3-P3, ...
#     chs : list | 23 items (EEG: 22, STIM: 1)
#     comps : list | 0 items
#     custom_ref_applied : bool | False
#     dev_head_t : Transform | 3 items
#     events : list | 0 items
#     highpass : float | 0.0 Hz
#     hpi_meas : list | 0 items
#     hpi_results : list | 0 items
#     lowpass : float | 128.0 Hz
#     meas_date : int | -571392300
#     nchan : int | 23
#     proc_history : list | 0 items
#     projs : list | 0 items
#     sfreq : float | 256.0 Hz
#     acq_pars : NoneType
#     acq_stim : NoneType
#     ctf_head_t : NoneType
#     description : NoneType
#     dev_ctf_t : NoneType
#     dig : NoneType
#     experimenter : NoneType
#     file_id : NoneType
#     gantry_angle : NoneType
#     hpi_subsystem : NoneType
#     kit_system_id : NoneType
#     line_freq : NoneType
#     meas_id : NoneType
#     proj_id : NoneType
#     proj_name : NoneType
#     subject_info : NoneType
#     xplotter_layout : NoneType
# >

# %% [markdown]
# Save memory

# %%
# print(test_df.info(memory_usage='deep'))
def mem_usage(pandas_obj):
    if isinstance(pandas_obj,pd.DataFrame):
        usage_b = pandas_obj.memory_usage(deep=True).sum()
    else: # we assume if not a df it's a series
        usage_b = pandas_obj.memory_usage(deep=True)
    usage_mb = usage_b / 1024 ** 2 # convert bytes to megabytes
    return "{:03.2f} MB".format(usage_mb)

# %%
def downcast_dtypes(df):
    _start = df.memory_usage(deep=True).sum() / 1024 ** 2
    float_cols = [c for c in df if df[c].dtype == 'float64']
    int_cols = [c for c in df if df[c].dtype in ['int64', 'int32']]
    df[float_cols] = df[float_cols].astype(np.float32)
    df[int_cols] = df[int_cols].astype(np.int16)
    _end = df.memory_usage(deep=True).sum() / 1024 ** 2
    saved_time = (_start - _end) / _start * 100
    #print(f"Saved: {saved_time:.2f}%")
    return df

# %% [markdown]
# format summary txt file

# %%
def read_format_info_file(txt_summary_file_path):
    str_container = ""
    with open(txt_summary_file_path, 'r') as f:
        for line in f:
            str_container += str(line).replace("\n", "<br>")

    formatted_str = re.findall('(.*?)<br><br>', str_container)
    bla = [x.group() for x in re.finditer('(.*?)<br><br>', str_container)]
    for index, line in enumerate(formatted_str):
        if re.match('(^Channels in EDF Files:|^Channels changed:)', line):
            formatted_str.remove(formatted_str[index])
        else:
            pass
    return formatted_str

# %%
class FileInformationContainer:
    def __init__(self, information_str):
        self.information_str = self.clean_string(information_str)
        self.file_name = self.set_filename()
        self.time_start = self.set_file_time_start_ms()
        self.sz_info = self.set_sz_information()
        
    def clean_string(self, uncleaned_str):
        return uncleaned_str.replace("<br>", " ")

    def set_filename(self):
        filename_found = re.match(r"^File Name: (.+?).edf", self.information_str)
        if filename_found:
            return filename_found.group(1)
        else:
            print(f"{self.file_name} failed get_filename")
            return "filename not found"
    
    def get_milli_sec(self, time_str):
        """Get Seconds from time."""
        dt_obj = datetime.strptime(time_str,'%H:%M:%S')
        millisec = dt_obj.timestamp() * 1000
        return millisec

    def set_file_time_start_ms(self):
        time_start_found = re.match(r".*File Start Time: (.*?) File", self.information_str)
        if time_start_found:
            try:
                return self.get_milli_sec(time_start_found.group(1))
            except Exception as e :
                print(f"{self.file_name}: error {e} cannot convert to ms time")
                return f"{e}"
        else:
            print(f"{self.file_name} failed get_file_time_start_ms")
            return "time start not found"
    
    def get_sz_count(self):
        sz_count = 0
        count_found = re.search(r".*Seizures in File: (.*?) Seizure", self.information_str)
        if count_found:
            sz_count = count_found.group(1)
        if int(sz_count) > 0:
            return int(sz_count)
        else:
            return 0
        

    def set_sz_information(self):
        if(type(self.get_sz_count()) != None and self.get_sz_count() > 0):
            try:
                pattern = re.compile(r"Seizure [1-9] (?P<state>[?:Start|End]+) Time: (?P<Sec>[0-9]+)")
                myList = [m.groupdict() for m in pattern.finditer(self.information_str)]
                if(len(myList) <= 0):
                     pattern = re.compile(r"Seizure (?P<state>[?:Start|End]+) Time: (?P<Sec>[0-9]+)")
                     myList = [m.groupdict() for m in pattern.finditer(self.information_str)]
                for item in myList:
                    converted_time = int(item.get("Sec"))
                    item["Sec"] = converted_time
                formatted = []
                for i in range(0, len(myList), 2):
                    formatted.append({"sz_start" : myList[i]["Sec"], "sz_end" : myList[i+1]["Sec"]})
                return formatted
            except Exception as e:
                print(f"set_sz_information failed at file: {self.file_name} with the following exception: {e}")
        else:
            return []

    def get(self):
        return self.information_str

# %% [markdown]
# Timestamp inserts

# %%
def insert_time_stamp(dataframe, file_start_time):
    period_row_increment_value =  (1 / 256) * 1000
    dataframe.insert(0, "timestamp", [file_start_time + i * period_row_increment_value for i in dataframe.index])

# %% [markdown]
# Insert classes

# %%
def insert_class_col(dataframe, sz_info_list):
    print(f"modtaget string: {sz_info_list}")
    
    if "class" not in dataframe.columns:
        dataframe.insert(0, "class", np.nan)

    if len(sz_info_list) == 0:
        dataframe.loc[(dataframe['class'] != "seizure") & (dataframe['class'] != "Preictal I") & (dataframe['class'] != "Preictal II"), "class"] = "Interictal"
    else:
        for item in sz_info_list:
            sz_start = item["sz_start"] * 256
            sz_end = item["sz_end"] * 256
            print(f"sz_start index = {sz_start}")
            print(f"sz_end: {sz_end}")
            preictal_two_start = sz_start - (15 * 60 * 256)
            actual_sz_end = dataframe.iloc[0]['timestamp'] + sz_end
            dataframe['timestamp'] = pd.to_numeric(dataframe['timestamp'])

            if preictal_two_start <= 0:
                preictal_two_start = 0
          

            # #INSERTING INTERICTAL
            # dataframe.loc[(dataframe['class'] != "seizure") | (dataframe['class'] != "Preictal I") | (dataframe['class'] != "Preictal II") | (dataframe['timestamp'] > actual_sz_end) | (dataframe['timestamp'] < actual_sz_start), "class"] = "Interictal"

            #INSERTING PREICTAL II
            dataframe['class'][preictal_two_start : sz_start] = "Preictal"

            #INSERTING SEIZURE CLASS
            dataframe['class'][sz_start: sz_end] = "seizure"

            dataframe.loc[(dataframe['class'] != "seizure") & (dataframe['class'] != "Preictal"), "class"] = "Interictal"

            #print(dataframe["class"].value_counts())

# %% [markdown]
# Compress and save

# %%
def df_save_compress(filename, df):
    df.to_csv(f"{save_csv_path}/{filename}.csv")

# %% [markdown]
# Run script

# %%
for patient in get_all_patient_folder_names(filtered_database_path):
    print(patient)
    current_patient = patient
    info_txt_path, edf_files = get_all_file_names(current_patient)
    # read & extract information
    info_txt = read_format_info_file(info_txt_path)
    for line in info_txt[1:]:
        #print(line)
        edf_info_container = FileInformationContainer(line)
        print(f"EDF_CONTAINER: info_string passed {edf_info_container.information_str}")
        print(f"EDF_CONTAINER: ts_start {edf_info_container.time_start}")
        print(f"EDF_CONTAINER: sz_info {edf_info_container.sz_info}")
        selected_edf_path = [x for x in edf_files if (edf_info_container.file_name in x)][0]
        edf_df = ReadEdfFile(selected_edf_path)
        if edf_info_container.get_sz_count() > 0:
            if edf_df is not None:
                #edf_df = downcast_dtypes(edf_df)
                insert_time_stamp(edf_df, edf_info_container.time_start)
                #print(f"info list = {edf_info_container.sz_info}")
                insert_class_col(edf_df, edf_info_container.sz_info)
                print(f"filename: {edf_info_container.file_name} classes: {edf_df['class'].value_counts()}")
                print("-------------------------------------------------------")
                print(edf_info_container.file_name)
                df_save_compress(edf_info_container.file_name, edf_df)
                print(f"saved: {edf_info_container.file_name}")
# Out:
# ../Dataset/CHB-MIT/Filtered-chb-mit//chb20
# EDF_CONTAINER: info_string passed File Name: chb20_01.edf File Start Time: 16:55:08 File End Time: 17:55:14 Number of Seizures in File: 0
# EDF_CONTAINER: ts_start -2208931492000.0
# EDF_CONTAINER: sz_info []
# EDF_CONTAINER: info_string passed File Name: chb20_02.edf File Start Time: 17:55:44 File End Time: 18:55:44 Number of Seizures in File: 0
# EDF_CONTAINER: ts_start -2208927856000.0
# EDF_CONTAINER: sz_info []
# EDF_CONTAINER: info_string passed File Name: chb20_03.edf File Start Time: 18:55:51 File End Time: 19:55:51 Number of Seizures in File: 0
# EDF_CONTAINER: ts_start -2208924249000.0
# EDF_CONTAINER: sz_info []
# EDF_CONTAINER: info_string passed File Name: chb20_04.edf File Start Time: 19:55:59 File End Time: 20:55:59 Number of Seizures in File: 0
# EDF_CONTAINER: ts_start -2208920641000.0
# EDF_CONTAINER: sz_info []
# EDF_CONTAINER: info_string passed File Name: chb20_05.edf File Start Time: 20:56:06 File End Time: 21:56:06 Number of Seizures in File: 0
# EDF_CONTAINER: ts_start -2208917034000.0
# EDF_CONTAINER: sz_info []
# EDF_CONTAINER: info_string passed File Name: chb20_06.edf File Start Time: 21:56:13 File End Time: 22:56:13 Number of Seizures in File: 0
# EDF_CONTAINER: ts_start -2208913427000.0
# EDF_CONTAINER: sz_info []
# EDF_CONTAINER: info_string passed File Name: chb20_07.edf File Start Time: 22:56:19 File End Time: 23:56:19 Number of Seizures in File: 0
# EDF_CONTAINER: ts_start -2208909821000.0
# EDF_CONTAINER: sz_info []
# EDF_CONTAINER: info_string passed File Name: chb20_08.edf File Start Time: 23:56:26 File End Time: 24:56:26 Number of Seizures in File: 0
# EDF_CONTAINER: ts_start -2208906214000.0
# EDF_CONTAINER: sz_info []
# EDF_CONTAINER: info_string passed File Name: chb20_11.edf File Start Time: 02:56:46 File End Time: 3:56:46 Number of Seizures in File: 0
# EDF_CONTAINER: ts_start -2208981794000.0
# EDF_CONTAINER: sz_info []
# EDF_CONTAINER: info_string passed File Name: chb20_12.edf File Start Time: 03:56:53 File End Time: 4:56:53 Number of Seizures in File: 1 Seizure 1 Start Time: 94 seconds Seizure 1 End Time: 123 seconds
# EDF_CONTAINER: ts_start -2208978187000.0
# EDF_CONTAINER: sz_info [{'sz_start': 94, 'sz_end': 123}]
# modtaget string: [{'sz_start': 94, 'sz_end': 123}]
# sz_start index = 24064
# sz_end: 31488
# filename: chb20_12 classes: Interictal    890112
# Preictal       24064
# seizure         7424
# Name: class, dtype: int64
# -------------------------------------------------------
# chb20_12
# saved: chb20_12
# EDF_CONTAINER: info_string passed File Name: chb20_13.edf File Start Time: 04:57:00 File End Time: 5:57:00 Number of Seizures in File: 2 Seizure 1 Start Time: 1440 seconds Seizure 1 End Time: 1470 seconds Seizure 2 Start Time: 2498 seconds Seizure 2 End Time: 2537 seconds
# EDF_CONTAINER: ts_start -2208974580000.0
# EDF_CONTAINER: sz_info [{'sz_start': 1440, 'sz_end': 1470}, {'sz_start': 2498, 'sz_end': 2537}]
# modtaget string: [{'sz_start': 1440, 'sz_end': 1470}, {'sz_start': 2498, 'sz_end': 2537}]
# sz_start index = 368640
# sz_end: 376320
# sz_start index = 639488
# sz_end: 649472
# filename: chb20_13 classes: Preictal      460800
# Interictal    443136
# seizure        17664
# Name: class, dtype: int64
# -------------------------------------------------------
# chb20_13
# /var/folders/0v/m6wt8rqj7s1dcljdyjrdfxmw0000gn/T/ipykernel_42368/4163325052.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframe['class'][preictal_two_start : sz_start] = "Preictal"
# /var/folders/0v/m6wt8rqj7s1dcljdyjrdfxmw0000gn/T/ipykernel_42368/4163325052.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframe['class'][sz_start: sz_end] = "seizure"
# saved: chb20_13
# EDF_CONTAINER: info_string passed File Name: chb20_14.edf File Start Time: 05:57:07 File End Time: 6:57:07 Number of Seizures in File: 1 Seizure 1 Start Time: 1971 seconds Seizure 1 End Time: 2009 seconds
# EDF_CONTAINER: ts_start -2208970973000.0
# EDF_CONTAINER: sz_info [{'sz_start': 1971, 'sz_end': 2009}]
# modtaget string: [{'sz_start': 1971, 'sz_end': 2009}]
# sz_start index = 504576
# sz_end: 514304
# filename: chb20_14 classes: Interictal    681472
# Preictal      230400
# seizure         9728
# Name: class, dtype: int64
# -------------------------------------------------------
# chb20_14
# saved: chb20_14
# EDF_CONTAINER: info_string passed File Name: chb20_15.edf File Start Time: 06:57:14 File End Time: 7:57:14 Number of Seizures in File: 2 Seizure 1 Start Time: 390 seconds Seizure 1 End Time: 425 seconds Seizure 2 Start Time: 1689 seconds Seizure 2 End Time: 1738 seconds
# EDF_CONTAINER: ts_start -2208967366000.0
# EDF_CONTAINER: sz_info [{'sz_start': 390, 'sz_end': 425}, {'sz_start': 1689, 'sz_end': 1738}]
# modtaget string: [{'sz_start': 390, 'sz_end': 425}, {'sz_start': 1689, 'sz_end': 1738}]
# sz_start index = 99840
# sz_end: 108800
# sz_start index = 432384
# sz_end: 444928
# filename: chb20_15 classes: Interictal    569856
# Preictal      330240
# seizure        21504
# Name: class, dtype: int64
# -------------------------------------------------------
# chb20_15
# saved: chb20_15
# EDF_CONTAINER: info_string passed File Name: chb20_16.edf File Start Time: 07:57:20 File End Time: 8:55:09 Number of Seizures in File: 1 Seizure 1 Start Time: 2226 seconds Seizure 1 End Time: 2261 seconds
# EDF_CONTAINER: ts_start -2208963760000.0
# EDF_CONTAINER: sz_info [{'sz_start': 2226, 'sz_end': 2261}]
# modtaget string: [{'sz_start': 2226, 'sz_end': 2261}]
# sz_start index = 569856
# sz_end: 578816
# filename: chb20_16 classes: Interictal    648704
# Preictal      230400
# seizure         8960
# Name: class, dtype: int64
# -------------------------------------------------------
# chb20_16
# saved: chb20_16
# EDF_CONTAINER: info_string passed File Name: chb20_17.edf File Start Time: 08:55:24 File End Time: 9:55:24 Number of Seizures in File: 0
# EDF_CONTAINER: ts_start -2208960276000.0
# EDF_CONTAINER: sz_info []
# EDF_CONTAINER: info_string passed File Name: chb20_21.edf File Start Time: 12:51:27 File End Time: 13:51:45 Number of Seizures in File: 0
# EDF_CONTAINER: ts_start -2208946113000.0
# EDF_CONTAINER: sz_info []
# EDF_CONTAINER: info_string passed File Name: chb20_22.edf File Start Time: 13:53:06 File End Time: 14:05:28 Number of Seizures in File: 0
# EDF_CONTAINER: ts_start -2208942414000.0
# EDF_CONTAINER: sz_info []
# EDF_CONTAINER: info_string passed File Name: chb20_23.edf File Start Time: 14:11:44 File End Time: 15:01:08 Number of Seizures in File: 0
# EDF_CONTAINER: ts_start -2208941296000.0
# EDF_CONTAINER: sz_info []
# EDF_CONTAINER: info_string passed File Name: chb20_25.edf File Start Time: 16:05:20 File End Time: 17:05:20 Number of Seizures in File: 0
# EDF_CONTAINER: ts_start -2208934480000.0
# EDF_CONTAINER: sz_info []
# EDF_CONTAINER: info_string passed File Name: chb20_26.edf File Start Time: 17:05:27 File End Time: 18:05:27 Number of Seizures in File: 0
# EDF_CONTAINER: ts_start -2208930873000.0
# EDF_CONTAINER: sz_info []
# EDF_CONTAINER: info_string passed File Name: chb20_27.edf File Start Time: 18:05:33 File End Time: 19:05:33 Number of Seizures in File: 0
# EDF_CONTAINER: ts_start -2208927267000.0
# EDF_CONTAINER: sz_info []
# EDF_CONTAINER: info_string passed File Name: chb20_28.edf File Start Time: 19:05:40 File End Time: 20:05:40 Number of Seizures in File: 0
# EDF_CONTAINER: ts_start -2208923660000.0
# EDF_CONTAINER: sz_info []
# EDF_CONTAINER: info_string passed File Name: chb20_29.edf File Start Time: 20:05:47 File End Time: 21:05:47 Number of Seizures in File: 0
# EDF_CONTAINER: ts_start -2208920053000.0
# EDF_CONTAINER: sz_info []
# EDF_CONTAINER: info_string passed File Name: chb20_30.edf File Start Time: 21:05:54 File End Time: 22:05:54 Number of Seizures in File: 0
# EDF_CONTAINER: ts_start -2208916446000.0
# EDF_CONTAINER: sz_info []
# EDF_CONTAINER: info_string passed File Name: chb20_31.edf File Start Time: 22:06:01 File End Time: 23:06:01 Number of Seizures in File: 0
# EDF_CONTAINER: ts_start -2208912839000.0
# EDF_CONTAINER: sz_info []
# EDF_CONTAINER: info_string passed File Name: chb20_34.edf File Start Time: 01:06:21 File End Time: 2:06:21 Number of Seizures in File: 0
# EDF_CONTAINER: ts_start -2208988419000.0
# EDF_CONTAINER: sz_info []
# EDF_CONTAINER: info_string passed File Name: chb20_59.edf File Start Time: 00:44:04 File End Time: 1:44:04 Number of Seizures in File: 0
# EDF_CONTAINER: ts_start -2208989756000.0
# EDF_CONTAINER: sz_info []
# EDF_CONTAINER: info_string passed File Name: chb20_60.edf File Start Time: 01:44:11 File End Time: 2:44:11 Number of Seizures in File: 0
# EDF_CONTAINER: ts_start -2208986149000.0
# EDF_CONTAINER: sz_info []
# ../Dataset/CHB-MIT/Filtered-chb-mit//chb18
# EDF_CONTAINER: info_string passed File Name: chb18_01.edf File Start Time: 17:53:23 File End Time: 18:53:34 Number of Seizures in File: 0
# EDF_CONTAINER: ts_start -2208927997000.0
# EDF_CONTAINER: sz_info []
# EDF_CONTAINER: info_string passed File Name: chb18_02.edf File Start Time: 18:54:57 File End Time: 19:54:57 Number of Seizures in File: 0
# EDF_CONTAINER: ts_start -2208924303000.0
# EDF_CONTAINER: sz_info []
# EDF_CONTAINER: info_string passed File Name: chb18_03.edf File Start Time: 19:55:04 File End Time: 20:55:04 Number of Seizures in File: 0
# EDF_CONTAINER: ts_start -2208920696000.0
# EDF_CONTAINER: sz_info []
# EDF_CONTAINER: info_string passed File Name: chb18_04.edf File Start Time: 20:55:11 File End Time: 21:55:11 Number of Seizures in File: 0
# EDF_CONTAINER: ts_start -2208917089000.0
# EDF_CONTAINER: sz_info []
# EDF_CONTAINER: info_string passed File Name: chb18_05.edf File Start Time: 21:55:18 File End Time: 22:55:18 Number of Seizures in File: 0
# EDF_CONTAINER: ts_start -2208913482000.0
# EDF_CONTAINER: sz_info []
# EDF_CONTAINER: info_string passed File Name: chb18_06.edf File Start Time: 22:55:25 File End Time: 23:55:25 Number of Seizures in File: 0
# EDF_CONTAINER: ts_start -2208909875000.0
# EDF_CONTAINER: sz_info []
# EDF_CONTAINER: info_string passed File Name: chb18_07.edf File Start Time: 23:55:32 File End Time: 24:55:32 Number of Seizures in File: 0
# EDF_CONTAINER: ts_start -2208906268000.0
# EDF_CONTAINER: sz_info []
# EDF_CONTAINER: info_string passed File Name: chb18_08.edf File Start Time: 00:55:38 File End Time: 1:55:38 Number of Seizures in File: 0
# EDF_CONTAINER: ts_start -2208989062000.0
# EDF_CONTAINER: sz_info []
# EDF_CONTAINER: info_string passed File Name: chb18_09.edf File Start Time: 01:55:45 File End Time: 2:55:45 Number of Seizures in File: 0
# EDF_CONTAINER: ts_start -2208985455000.0
# EDF_CONTAINER: sz_info []
# EDF_CONTAINER: info_string passed File Name: chb18_10.edf File Start Time: 02:55:52 File End Time: 3:55:52 Number of Seizures in File: 0
# EDF_CONTAINER: ts_start -2208981848000.0
# EDF_CONTAINER: sz_info []
# EDF_CONTAINER: info_string passed File Name: chb18_11.edf File Start Time: 03:55:59 File End Time: 4:55:59 Number of Seizures in File: 0
# EDF_CONTAINER: ts_start -2208978241000.0
# EDF_CONTAINER: sz_info []
# EDF_CONTAINER: info_string passed File Name: chb18_12.edf File Start Time: 04:56:06 File End Time: 5:56:06 Number of Seizures in File: 0
# EDF_CONTAINER: ts_start -2208974634000.0
# EDF_CONTAINER: sz_info []
# EDF_CONTAINER: info_string passed File Name: chb18_13.edf File Start Time: 05:56:13 File End Time: 6:56:13 Number of Seizures in File: 0
# EDF_CONTAINER: ts_start -2208971027000.0
# EDF_CONTAINER: sz_info []
# EDF_CONTAINER: info_string passed File Name: chb18_14.edf File Start Time: 06:56:19 File End Time: 7:56:19 Number of Seizures in File: 0
# EDF_CONTAINER: ts_start -2208967421000.0
# EDF_CONTAINER: sz_info []
# EDF_CONTAINER: info_string passed File Name: chb18_15.edf File Start Time: 07:56:26 File End Time: 8:56:26 Number of Seizures in File: 0
# EDF_CONTAINER: ts_start -2208963814000.0
# EDF_CONTAINER: sz_info []
# EDF_CONTAINER: info_string passed File Name: chb18_16.edf File Start Time: 08:56:33 File End Time: 9:56:33 Number of Seizures in File: 0
# EDF_CONTAINER: ts_start -2208960207000.0
# EDF_CONTAINER: sz_info []
# EDF_CONTAINER: info_string passed File Name: chb18_17.edf File Start Time: 09:56:40 File End Time: 10:56:40 Number of Seizures in File: 0
# EDF_CONTAINER: ts_start -2208956600000.0
# EDF_CONTAINER: sz_info []
# EDF_CONTAINER: info_string passed File Name: chb18_18.edf File Start Time: 16:57:30 File End Time: 17:57:30 Number of Seizures in File: 0
# EDF_CONTAINER: ts_start -2208931350000.0
# EDF_CONTAINER: sz_info []
# EDF_CONTAINER: info_string passed File Name: chb18_19.edf File Start Time: 17:57:37 File End Time: 18:57:37 Number of Seizures in File: 0
# EDF_CONTAINER: ts_start -2208927743000.0
# EDF_CONTAINER: sz_info []
# EDF_CONTAINER: info_string passed File Name: chb18_20.edf File Start Time: 18:57:44 File End Time: 19:57:44 Number of Seizures in File: 0
# EDF_CONTAINER: ts_start -2208924136000.0
# EDF_CONTAINER: sz_info []
# EDF_CONTAINER: info_string passed File Name: chb18_21.edf File Start Time: 19:57:50 File End Time: 20:57:50 Number of Seizures in File: 0
# EDF_CONTAINER: ts_start -2208920530000.0
# EDF_CONTAINER: sz_info []
# EDF_CONTAINER: info_string passed File Name: chb18_22.edf File Start Time: 20:57:57 File End Time: 21:57:57 Number of Seizures in File: 0
# EDF_CONTAINER: ts_start -2208916923000.0
# EDF_CONTAINER: sz_info []
# EDF_CONTAINER: info_string passed File Name: chb18_23.edf File Start Time: 23:58:18 File End Time: 24:58:18 Number of Seizures in File: 0
# EDF_CONTAINER: ts_start -2208906102000.0
# EDF_CONTAINER: sz_info []
# EDF_CONTAINER: info_string passed File Name: chb18_24.edf File Start Time: 00:58:25 File End Time: 1:58:25 Number of Seizures in File: 0
# EDF_CONTAINER: ts_start -2208988895000.0
# EDF_CONTAINER: sz_info []
# EDF_CONTAINER: info_string passed File Name: chb18_25.edf File Start Time: 01:58:31 File End Time: 2:58:31 Number of Seizures in File: 0
# EDF_CONTAINER: ts_start -2208985289000.0
# EDF_CONTAINER: sz_info []
# EDF_CONTAINER: info_string passed File Name: chb18_26.edf File Start Time: 02:58:38 File End Time: 3:58:38 Number of Seizures in File: 0
# EDF_CONTAINER: ts_start -2208981682000.0
# EDF_CONTAINER: sz_info []
# EDF_CONTAINER: info_string passed File Name: chb18_27.edf File Start Time: 03:58:45 File End Time: 4:58:45 Number of Seizures in File: 0
# EDF_CONTAINER: ts_start -2208978075000.0
# EDF_CONTAINER: sz_info []
# EDF_CONTAINER: info_string passed File Name: chb18_28.edf File Start Time: 04:58:52 File End Time: 5:58:52 Number of Seizures in File: 0
# EDF_CONTAINER: ts_start -2208974468000.0
# EDF_CONTAINER: sz_info []
# EDF_CONTAINER: info_string passed File Name: chb18_29.edf File Start Time: 05:58:59 File End Time: 6:58:59 Number of Seizures in File: 1 Seizure 1 Start Time: 3477 seconds Seizure 1 End Time: 3527 seconds
# EDF_CONTAINER: ts_start -2208970861000.0
# EDF_CONTAINER: sz_info [{'sz_start': 3477, 'sz_end': 3527}]
# modtaget string: [{'sz_start': 3477, 'sz_end': 3527}]
# sz_start index = 890112
# sz_end: 902912
# filename: chb18_29 classes: Interictal    678400
# Preictal      230400
# seizure        12800
# Name: class, dtype: int64
# -------------------------------------------------------
# chb18_29
# saved: chb18_29
# EDF_CONTAINER: info_string passed File Name: chb18_30.edf File Start Time: 06:59:06 File End Time: 7:59:06 Number of Seizures in File: 1 Seizure 1 Start Time: 541 seconds Seizure 1 End Time: 571 seconds
# EDF_CONTAINER: ts_start -2208967254000.0
# EDF_CONTAINER: sz_info [{'sz_start': 541, 'sz_end': 571}]
# modtaget string: [{'sz_start': 541, 'sz_end': 571}]
# sz_start index = 138496
# sz_end: 146176
# filename: chb18_30 classes: Interictal    775424
# Preictal      138496
# seizure         7680
# Name: class, dtype: int64
# -------------------------------------------------------
# chb18_30
# saved: chb18_30
# EDF_CONTAINER: info_string passed File Name: chb18_31.edf File Start Time: 10:00:32 File End Time: 10:38:26 Number of Seizures in File: 1 Seizure 1 Start Time: 2087 seconds Seizure 1 End Time: 2155 seconds
# EDF_CONTAINER: ts_start -2208956368000.0
# EDF_CONTAINER: sz_info [{'sz_start': 2087, 'sz_end': 2155}]
# modtaget string: [{'sz_start': 2087, 'sz_end': 2155}]
# sz_start index = 534272
# sz_end: 551680
# filename: chb18_31 classes: Interictal    334336
# Preictal      230400
# seizure        17408
# Name: class, dtype: int64
# -------------------------------------------------------
# chb18_31
# saved: chb18_31
# EDF_CONTAINER: info_string passed File Name: chb18_32.edf File Start Time: 11:38:42 File End Time: 12:38:42 Number of Seizures in File: 1 Seizure 1 Start Time: 1908 seconds Seizure 1 End Time: 1963 seconds
# EDF_CONTAINER: ts_start -2208950478000.0
# EDF_CONTAINER: sz_info [{'sz_start': 1908, 'sz_end': 1963}]
# modtaget string: [{'sz_start': 1908, 'sz_end': 1963}]
# sz_start index = 488448
# sz_end: 502528
# filename: chb18_32 classes: Interictal    677120
# Preictal      230400
# seizure        14080
# Name: class, dtype: int64
# -------------------------------------------------------
# chb18_32
# saved: chb18_32
# EDF_CONTAINER: info_string passed File Name: chb18_33.edf File Start Time: 15:39:10 File End Time: 16:39:10 Number of Seizures in File: 0
# EDF_CONTAINER: ts_start -2208936050000.0
# EDF_CONTAINER: sz_info []
# EDF_CONTAINER: info_string passed File Name: chb18_34.edf File Start Time: 19:40:40 File End Time: 20:40:40 Number of Seizures in File: 0
# EDF_CONTAINER: ts_start -2208921560000.0
# EDF_CONTAINER: sz_info []
# EDF_CONTAINER: info_string passed File Name: chb18_35.edf File Start Time: 08:42:06 File End Time: 9:42:06 Number of Seizures in File: 1 Seizure 1 Start Time: 2196 seconds Seizure 1 End Time: 2264 seconds
# EDF_CONTAINER: ts_start -2208961074000.0
# EDF_CONTAINER: sz_info [{'sz_start': 2196, 'sz_end': 2264}]
# modtaget string: [{'sz_start': 2196, 'sz_end': 2264}]
# sz_start index = 562176
# sz_end: 579584
# filename: chb18_35 classes: Interictal    673792
# Preictal      230400
# seizure        17408
# Name: class, dtype: int64
# -------------------------------------------------------
# chb18_35
# saved: chb18_35
# ../Dataset/CHB-MIT/Filtered-chb-mit//chb19
# EDF_CONTAINER: info_string passed File Name: chb19_01.edf File Start Time: 17:36:30 File End Time: 18:36:30 Number of Seizures in File: 0
# EDF_CONTAINER: ts_start -2208929010000.0
# EDF_CONTAINER: sz_info []
# EDF_CONTAINER: info_string passed File Name: chb19_02.edf File Start Time: 18:36:32 File End Time: 19:36:32 Number of Seizures in File: 0
# EDF_CONTAINER: ts_start -2208925408000.0
# EDF_CONTAINER: sz_info []
# EDF_CONTAINER: info_string passed File Name: chb19_03.edf File Start Time: 19:36:40 File End Time: 20:36:40 Number of Seizures in File: 0
# EDF_CONTAINER: ts_start -2208921800000.0
# EDF_CONTAINER: sz_info []
# EDF_CONTAINER: info_string passed File Name: chb19_04.edf File Start Time: 20:36:46 File End Time: 21:36:46 Number of Seizures in File: 0
# EDF_CONTAINER: ts_start -2208918194000.0
# EDF_CONTAINER: sz_info []
# EDF_CONTAINER: info_string passed File Name: chb19_05.edf File Start Time: 21:36:53 File End Time: 22:36:53 Number of Seizures in File: 0
# EDF_CONTAINER: ts_start -2208914587000.0
# EDF_CONTAINER: sz_info []
# EDF_CONTAINER: info_string passed File Name: chb19_06.edf File Start Time: 22:37:00 File End Time: 23:37:00 Number of Seizures in File: 0
# EDF_CONTAINER: ts_start -2208910980000.0
# EDF_CONTAINER: sz_info []
# EDF_CONTAINER: info_string passed File Name: chb19_07.edf File Start Time: 23:37:07 File End Time: 24:37:07 Number of Seizures in File: 0
# EDF_CONTAINER: ts_start -2208907373000.0
# EDF_CONTAINER: sz_info []
# EDF_CONTAINER: info_string passed File Name: chb19_08.edf File Start Time: 00:37:14 File End Time: 1:37:14 Number of Seizures in File: 0
# EDF_CONTAINER: ts_start -2208990166000.0
# EDF_CONTAINER: sz_info []
# EDF_CONTAINER: info_string passed File Name: chb19_09.edf File Start Time: 01:37:20 File End Time: 2:37:20 Number of Seizures in File: 0
# EDF_CONTAINER: ts_start -2208986560000.0
# EDF_CONTAINER: sz_info []
# EDF_CONTAINER: info_string passed File Name: chb19_10.edf File Start Time: 02:37:27 File End Time: 3:37:27 Number of Seizures in File: 0
# EDF_CONTAINER: ts_start -2208982953000.0
# EDF_CONTAINER: sz_info []
# EDF_CONTAINER: info_string passed File Name: chb19_11.edf File Start Time: 03:37:34 File End Time: 4:37:34 Number of Seizures in File: 0
# EDF_CONTAINER: ts_start -2208979346000.0
# EDF_CONTAINER: sz_info []
# EDF_CONTAINER: info_string passed File Name: chb19_12.edf File Start Time: 04:37:41 File End Time: 5:37:41 Number of Seizures in File: 0
# EDF_CONTAINER: ts_start -2208975739000.0
# EDF_CONTAINER: sz_info []
# EDF_CONTAINER: info_string passed File Name: chb19_13.edf File Start Time: 05:37:47 File End Time: 6:37:47 Number of Seizures in File: 0
# EDF_CONTAINER: ts_start -2208972133000.0
# EDF_CONTAINER: sz_info []
# EDF_CONTAINER: info_string passed File Name: chb19_14.edf File Start Time: 06:37:54 File End Time: 7:37:54 Number of Seizures in File: 0
# EDF_CONTAINER: ts_start -2208968526000.0
# EDF_CONTAINER: sz_info []
# EDF_CONTAINER: info_string passed File Name: chb19_15.edf File Start Time: 07:38:01 File End Time: 8:38:01 Number of Seizures in File: 0
# EDF_CONTAINER: ts_start -2208964919000.0
# EDF_CONTAINER: sz_info []
# EDF_CONTAINER: info_string passed File Name: chb19_16.edf File Start Time: 08:38:08 File End Time: 9:38:08 Number of Seizures in File: 0
# EDF_CONTAINER: ts_start -2208961312000.0
# EDF_CONTAINER: sz_info []
# EDF_CONTAINER: info_string passed File Name: chb19_17.edf File Start Time: 12:38:35 File End Time: 13:38:35 Number of Seizures in File: 0
# EDF_CONTAINER: ts_start -2208946885000.0
# EDF_CONTAINER: sz_info []
# EDF_CONTAINER: info_string passed File Name: chb19_18.edf File Start Time: 13:38:42 File End Time: 14:38:42 Number of Seizures in File: 0
# EDF_CONTAINER: ts_start -2208943278000.0
# EDF_CONTAINER: sz_info []
# EDF_CONTAINER: info_string passed File Name: chb19_19.edf File Start Time: 14:38:48 File End Time: 15:38:48 Number of Seizures in File: 0
# EDF_CONTAINER: ts_start -2208939672000.0
# EDF_CONTAINER: sz_info []
# EDF_CONTAINER: info_string passed File Name: chb19_20.edf File Start Time: 15:38:55 File End Time: 16:38:55 Number of Seizures in File: 0
# EDF_CONTAINER: ts_start -2208936065000.0
# EDF_CONTAINER: sz_info []
# EDF_CONTAINER: info_string passed File Name: chb19_21.edf File Start Time: 16:39:02 File End Time: 17:39:02 Number of Seizures in File: 0
# EDF_CONTAINER: ts_start -2208932458000.0
# EDF_CONTAINER: sz_info []
# EDF_CONTAINER: info_string passed File Name: chb19_22.edf File Start Time: 22:39:42 File End Time: 23:39:42 Number of Seizures in File: 0
# EDF_CONTAINER: ts_start -2208910818000.0
# EDF_CONTAINER: sz_info []
# EDF_CONTAINER: info_string passed File Name: chb19_23.edf File Start Time: 23:39:49 File End Time: 24:39:49 Number of Seizures in File: 0
# EDF_CONTAINER: ts_start -2208907211000.0
# EDF_CONTAINER: sz_info []
# EDF_CONTAINER: info_string passed File Name: chb19_24.edf File Start Time: 00:39:56 File End Time: 1:39:56 Number of Seizures in File: 0
# EDF_CONTAINER: ts_start -2208990004000.0
# EDF_CONTAINER: sz_info []
# EDF_CONTAINER: info_string passed File Name: chb19_25.edf File Start Time: 01:40:02 File End Time: 2:40:02 Number of Seizures in File: 0
# EDF_CONTAINER: ts_start -2208986398000.0
# EDF_CONTAINER: sz_info []
# EDF_CONTAINER: info_string passed File Name: chb19_26.edf File Start Time: 04:40:23 File End Time: 5:40:23 Number of Seizures in File: 0
# EDF_CONTAINER: ts_start -2208975577000.0
# EDF_CONTAINER: sz_info []
# EDF_CONTAINER: info_string passed File Name: chb19_27.edf File Start Time: 03:03:38 File End Time: 4:03:38 Number of Seizures in File: 0
# EDF_CONTAINER: ts_start -2208981382000.0
# EDF_CONTAINER: sz_info []
# EDF_CONTAINER: info_string passed File Name: chb19_28.edf File Start Time: 01:09:35 File End Time: 2:09:47 Number of Seizures in File: 1 Seizure 1 Start Time: 299 seconds Seizure 1 End Time: 377 seconds
# EDF_CONTAINER: ts_start -2208988225000.0
# EDF_CONTAINER: sz_info [{'sz_start': 299, 'sz_end': 377}]
# EDF_CONTAINER: info_string passed File Name: chb19_29.edf File Start Time: 07:11:12 File End Time: 8:11:12 Number of Seizures in File: 1 Seizure 1 Start Time: 2964 seconds Seizure 1 End Time: 3041 seconds
# EDF_CONTAINER: ts_start -2208966528000.0
# EDF_CONTAINER: sz_info [{'sz_start': 2964, 'sz_end': 3041}]
# ../Dataset/CHB-MIT/Filtered-chb-mit//chb21
# EDF_CONTAINER: info_string passed File Name: chb21_01.edf File Start Time: 17:56:45 File End Time: 18:56:45 Number of Seizures in File: 0
# EDF_CONTAINER: ts_start -2208927795000.0
# EDF_CONTAINER: sz_info []
# EDF_CONTAINER: info_string passed File Name: chb21_02.edf File Start Time: 18:56:49 File End Time: 19:56:49 Number of Seizures in File: 0
# EDF_CONTAINER: ts_start -2208924191000.0
# EDF_CONTAINER: sz_info []
# EDF_CONTAINER: info_string passed File Name: chb21_03.edf File Start Time: 19:56:57 File End Time: 20:56:57 Number of Seizures in File: 0
# EDF_CONTAINER: ts_start -2208920583000.0
# EDF_CONTAINER: sz_info []
# EDF_CONTAINER: info_string passed File Name: chb21_04.edf File Start Time: 20:57:04 File End Time: 21:57:04 Number of Seizures in File: 0
# EDF_CONTAINER: ts_start -2208916976000.0
# EDF_CONTAINER: sz_info []
# EDF_CONTAINER: info_string passed File Name: chb21_05.edf File Start Time: 21:57:11 File End Time: 22:57:11 Number of Seizures in File: 0
# EDF_CONTAINER: ts_start -2208913369000.0
# EDF_CONTAINER: sz_info []
# EDF_CONTAINER: info_string passed File Name: chb21_06.edf File Start Time: 22:57:18 File End Time: 23:57:18 Number of Seizures in File: 0
# EDF_CONTAINER: ts_start -2208909762000.0
# EDF_CONTAINER: sz_info []
# EDF_CONTAINER: info_string passed File Name: chb21_07.edf File Start Time: 23:57:24 File End Time: 24:57:24 Number of Seizures in File: 0
# EDF_CONTAINER: ts_start -2208906156000.0
# EDF_CONTAINER: sz_info []
# EDF_CONTAINER: info_string passed File Name: chb21_08.edf File Start Time: 00:57:31 File End Time: 1:57:31 Number of Seizures in File: 0
# EDF_CONTAINER: ts_start -2208988949000.0
# EDF_CONTAINER: sz_info []
# EDF_CONTAINER: info_string passed File Name: chb21_09.edf File Start Time: 01:57:38 File End Time: 2:57:38 Number of Seizures in File: 0
# EDF_CONTAINER: ts_start -2208985342000.0
# EDF_CONTAINER: sz_info []
# EDF_CONTAINER: info_string passed File Name: chb21_10.edf File Start Time: 02:57:45 File End Time: 3:57:45 Number of Seizures in File: 0
# EDF_CONTAINER: ts_start -2208981735000.0
# EDF_CONTAINER: sz_info []
# EDF_CONTAINER: info_string passed File Name: chb21_11.edf File Start Time: 03:57:52 File End Time: 4:57:52 Number of Seizures in File: 0
# EDF_CONTAINER: ts_start -2208978128000.0
# EDF_CONTAINER: sz_info []
# EDF_CONTAINER: info_string passed File Name: chb21_12.edf File Start Time: 04:57:59 File End Time: 5:57:59 Number of Seizures in File: 0
# EDF_CONTAINER: ts_start -2208974521000.0
# EDF_CONTAINER: sz_info []
# EDF_CONTAINER: info_string passed File Name: chb21_13.edf File Start Time: 05:58:06 File End Time: 6:58:06 Number of Seizures in File: 0
# EDF_CONTAINER: ts_start -2208970914000.0
# EDF_CONTAINER: sz_info []
# EDF_CONTAINER: info_string passed File Name: chb21_14.edf File Start Time: 06:58:13 File End Time: 7:58:13 Number of Seizures in File: 0
# EDF_CONTAINER: ts_start -2208967307000.0
# EDF_CONTAINER: sz_info []
# EDF_CONTAINER: info_string passed File Name: chb21_15.edf File Start Time: 07:58:20 File End Time: 8:58:20 Number of Seizures in File: 0
# EDF_CONTAINER: ts_start -2208963700000.0
# EDF_CONTAINER: sz_info []
# EDF_CONTAINER: info_string passed File Name: chb21_16.edf File Start Time: 08:58:27 File End Time: 9:58:26 Number of Seizures in File: 0
# EDF_CONTAINER: ts_start -2208960093000.0
# EDF_CONTAINER: sz_info []
# EDF_CONTAINER: info_string passed File Name: chb21_17.edf File Start Time: 09:58:59 File End Time: 10:58:59 Number of Seizures in File: 0
# EDF_CONTAINER: ts_start -2208956461000.0
# EDF_CONTAINER: sz_info []
# EDF_CONTAINER: info_string passed File Name: chb21_18.edf File Start Time: 10:59:06 File End Time: 11:59:06 Number of Seizures in File: 0
# EDF_CONTAINER: ts_start -2208952854000.0
# EDF_CONTAINER: sz_info []
# EDF_CONTAINER: info_string passed File Name: chb21_19.edf File Start Time: 11:59:13 File End Time: 12:59:13 Number of Seizures in File: 1 Seizure 1 Start Time: 1288 seconds Seizure 1 End Time: 1344 seconds
# EDF_CONTAINER: ts_start -2208949247000.0
# EDF_CONTAINER: sz_info [{'sz_start': 1288, 'sz_end': 1344}]
# EDF_CONTAINER: info_string passed File Name: chb21_20.edf File Start Time: 12:59:20 File End Time: 13:49:10 Number of Seizures in File: 1 Seizure 1 Start Time: 2627 seconds Seizure 1 End Time: 2677 seconds
# EDF_CONTAINER: ts_start -2208945640000.0
# EDF_CONTAINER: sz_info [{'sz_start': 2627, 'sz_end': 2677}]
# EDF_CONTAINER: info_string passed File Name: chb21_21.edf File Start Time: 15:49:35 File End Time: 16:49:35 Number of Seizures in File: 1 Seizure 1 Start Time: 2003 seconds Seizure 1 End Time: 2084 seconds
# EDF_CONTAINER: ts_start -2208935425000.0
# EDF_CONTAINER: sz_info [{'sz_start': 2003, 'sz_end': 2084}]
# EDF_CONTAINER: info_string passed File Name: chb21_22.edf File Start Time: 16:49:42 File End Time: 17:49:42 Number of Seizures in File: 1 Seizure 1 Start Time: 2553 seconds Seizure 1 End Time: 2565 seconds
# EDF_CONTAINER: ts_start -2208931818000.0
# EDF_CONTAINER: sz_info [{'sz_start': 2553, 'sz_end': 2565}]
# EDF_CONTAINER: info_string passed File Name: chb21_23.edf File Start Time: 18:36:01 File End Time: 19:36:01 Number of Seizures in File: 0
# EDF_CONTAINER: ts_start -2208925439000.0
# EDF_CONTAINER: sz_info []
# EDF_CONTAINER: info_string passed File Name: chb21_24.edf File Start Time: 20:36:11 File End Time: 21:36:11 Number of Seizures in File: 0
# EDF_CONTAINER: ts_start -2208918229000.0
# EDF_CONTAINER: sz_info []
# EDF_CONTAINER: info_string passed File Name: chb21_25.edf File Start Time: 22:36:25 File End Time: 23:36:25 Number of Seizures in File: 0
# EDF_CONTAINER: ts_start -2208911015000.0
# EDF_CONTAINER: sz_info []
# EDF_CONTAINER: info_string passed File Name: chb21_26.edf File Start Time: 23:36:32 File End Time: 24:36:32 Number of Seizures in File: 0
# EDF_CONTAINER: ts_start -2208907408000.0
# EDF_CONTAINER: sz_info []
# EDF_CONTAINER: info_string passed File Name: chb21_27.edf File Start Time: 00:36:39 File End Time: 1:36:39 Number of Seizures in File: 0
# EDF_CONTAINER: ts_start -2208990201000.0
# EDF_CONTAINER: sz_info []
# EDF_CONTAINER: info_string passed File Name: chb21_28.edf File Start Time: 01:36:46 File End Time: 2:36:46 Number of Seizures in File: 0
# EDF_CONTAINER: ts_start -2208986594000.0
# EDF_CONTAINER: sz_info []
# EDF_CONTAINER: info_string passed File Name: chb21_29.edf File Start Time: 08:37:34 File End Time: 9:37:34 Number of Seizures in File: 0
# EDF_CONTAINER: ts_start -2208961346000.0
# EDF_CONTAINER: sz_info []
# EDF_CONTAINER: info_string passed File Name: chb21_30.edf File Start Time: 13:38:08 File End Time: 14:38:08 Number of Seizures in File: 0
# EDF_CONTAINER: ts_start -2208943312000.0
# EDF_CONTAINER: sz_info []
# EDF_CONTAINER: info_string passed File Name: chb21_31.edf File Start Time: 22:39:10 File End Time: 23:39:10 Number of Seizures in File: 0
# EDF_CONTAINER: ts_start -2208910850000.0
# EDF_CONTAINER: sz_info []
# EDF_CONTAINER: info_string passed File Name: chb21_32.edf File Start Time: 23:39:17 File End Time: 24:39:17 Number of Seizures in File: 0
# EDF_CONTAINER: ts_start -2208907243000.0
# EDF_CONTAINER: sz_info []
# ../Dataset/CHB-MIT/Filtered-chb-mit//chb17
# EDF_CONTAINER: info_string passed File Name: chb17a_03.edf File Start Time: 19:47:38 File End Time: 20:47:38 Number of Seizures in File: 1 Seizure 1 Start Time: 2282 seconds Seizure 1 End Time: 2372 seconds
# EDF_CONTAINER: ts_start -2208921142000.0
# EDF_CONTAINER: sz_info [{'sz_start': 2282, 'sz_end': 2372}]
# EDF_CONTAINER: info_string passed File Name: chb17a_04.edf File Start Time: 20:47:45 File End Time: 21:47:45 Number of Seizures in File: 1 Seizure 1 Start Time: 3025 seconds Seizure 1 End Time: 3140 seconds
# EDF_CONTAINER: ts_start -2208917535000.0
# EDF_CONTAINER: sz_info [{'sz_start': 3025, 'sz_end': 3140}]
# EDF_CONTAINER: info_string passed File Name: chb17a_05.edf File Start Time: 21:47:52 File End Time: 22:47:52 Number of Seizures in File: 0
# EDF_CONTAINER: ts_start -2208913928000.0
# EDF_CONTAINER: sz_info []
# EDF_CONTAINER: info_string passed File Name: chb17a_06.edf File Start Time: 22:47:59 File End Time: 23:47:59 Number of Seizures in File: 0
# EDF_CONTAINER: ts_start -2208910321000.0
# EDF_CONTAINER: sz_info []
# EDF_CONTAINER: info_string passed File Name: chb17a_08.edf File Start Time: 00:48:39 File End Time: 1:48:39 Number of Seizures in File: 0
# EDF_CONTAINER: ts_start -2208989481000.0
# EDF_CONTAINER: sz_info []
# EDF_CONTAINER: info_string passed File Name: chb17b_57.edf File Start Time: 01:59:21 File End Time: 2:59:21 Number of Seizures in File: 0
# EDF_CONTAINER: ts_start -2208985239000.0
# EDF_CONTAINER: sz_info []
# EDF_CONTAINER: info_string passed File Name: chb17b_58.edf File Start Time: 02:59:28 File End Time: 3:59:28 Number of Seizures in File: 0
# EDF_CONTAINER: ts_start -2208981632000.0
# EDF_CONTAINER: sz_info []
# EDF_CONTAINER: info_string passed File Name: chb17b_59.edf File Start Time: 03:59:35 File End Time: 4:59:35 Number of Seizures in File: 0
# EDF_CONTAINER: ts_start -2208978025000.0
# EDF_CONTAINER: sz_info []
# EDF_CONTAINER: info_string passed File Name: chb17b_60.edf File Start Time: 04:59:41 File End Time: 5:59:41 Number of Seizures in File: 0
# EDF_CONTAINER: ts_start -2208974419000.0
# EDF_CONTAINER: sz_info []
# EDF_CONTAINER: info_string passed File Name: chb17b_63.edf File Start Time: 08:00:02 File End Time: 9:00:26 Number of Seizures in File: 1 Seizure 1 Start Time: 3136 seconds Seizure 1 End Time: 3224 seconds
# EDF_CONTAINER: ts_start -2208963598000.0
# EDF_CONTAINER: sz_info [{'sz_start': 3136, 'sz_end': 3224}]
# EDF_CONTAINER: info_string passed File Name: chb17b_67.edf File Start Time: 11:40:36 File End Time: 12:40:36 Number of Seizures in File: 0
# EDF_CONTAINER: ts_start -2208950364000.0
# EDF_CONTAINER: sz_info []
# EDF_CONTAINER: info_string passed File Name: chb17b_68.edf File Start Time: 12:40:43 File End Time: 13:40:43 Number of Seizures in File: 0
# EDF_CONTAINER: ts_start -2208946757000.0
# EDF_CONTAINER: sz_info []
# EDF_CONTAINER: info_string passed File Name: chb17b_69.edf File Start Time: 13:40:50 File End Time: 14:40:50 Number of Seizures in File: 0
# EDF_CONTAINER: ts_start -2208943150000.0
# EDF_CONTAINER: sz_info []
# EDF_CONTAINER: info_string passed File Name: chb17c_02.edf File Start Time: 22:53:46 File End Time: 23:53:46 Number of Seizures in File: 0
# EDF_CONTAINER: ts_start -2208909974000.0
# EDF_CONTAINER: sz_info []
# EDF_CONTAINER: info_string passed File Name: chb17c_03.edf File Start Time: 23:53:53 File End Time: 24:53:53 Number of Seizures in File: 0
# EDF_CONTAINER: ts_start -2208906367000.0
# EDF_CONTAINER: sz_info []
# EDF_CONTAINER: info_string passed File Name: chb17c_04.edf File Start Time: 00:54:00 File End Time: 1:54:00 Number of Seizures in File: 0
# EDF_CONTAINER: ts_start -2208989160000.0
# EDF_CONTAINER: sz_info []
# EDF_CONTAINER: info_string passed File Name: chb17c_05.edf File Start Time: 01:54:06 File End Time: 2:54:06 Number of Seizures in File: 0
# EDF_CONTAINER: ts_start -2208985554000.0
# EDF_CONTAINER: sz_info []
# EDF_CONTAINER: info_string passed File Name: chb17c_06.edf File Start Time: 02:54:13 File End Time: 3:54:13 Number of Seizures in File: 0
# EDF_CONTAINER: ts_start -2208981947000.0
# EDF_CONTAINER: sz_info []
# EDF_CONTAINER: info_string passed File Name: chb17c_07.edf File Start Time: 03:54:20 File End Time: 4:54:20 Number of Seizures in File: 0
# EDF_CONTAINER: ts_start -2208978340000.0
# EDF_CONTAINER: sz_info []
# EDF_CONTAINER: info_string passed File Name: chb17c_08.edf File Start Time: 04:54:27 File End Time: 5:54:27 Number of Seizures in File: 0
# EDF_CONTAINER: ts_start -2208974733000.0
# EDF_CONTAINER: sz_info []
# EDF_CONTAINER: info_string passed File Name: chb17c_13.edf File Start Time: 09:59:42 File End Time: 10:59:42 Number of Seizures in File: 0
# EDF_CONTAINER: ts_start -2208956418000.0
# EDF_CONTAINER: sz_info []
# ../Dataset/CHB-MIT/Filtered-chb-mit//chb10
# EDF_CONTAINER: info_string passed File Name: chb10_01.edf File Start Time: 17:52:43 File End Time: 19:53:03 Number of Seizures in File: 0
# EDF_CONTAINER: ts_start -2208928037000.0
# EDF_CONTAINER: sz_info []
# EDF_CONTAINER: info_string passed File Name: chb10_02.edf File Start Time: 19:53:45 File End Time: 21:53:45 Number of Seizures in File: 0
# EDF_CONTAINER: ts_start -2208920775000.0
# EDF_CONTAINER: sz_info []
# EDF_CONTAINER: info_string passed File Name: chb10_03.edf File Start Time: 21:53:52 File End Time: 23:53:52 Number of Seizures in File: 0
# EDF_CONTAINER: ts_start -2208913568000.0
# EDF_CONTAINER: sz_info []
# EDF_CONTAINER: info_string passed File Name: chb10_04.edf File Start Time: 23:54:00 File End Time: 25:54:00 Number of Seizures in File: 0
# EDF_CONTAINER: ts_start -2208906360000.0
# EDF_CONTAINER: sz_info []
# EDF_CONTAINER: info_string passed File Name: chb10_05.edf File Start Time: 01:54:07 File End Time: 3:54:07 Number of Seizures in File: 0
# EDF_CONTAINER: ts_start -2208985553000.0
# EDF_CONTAINER: sz_info []
# EDF_CONTAINER: info_string passed File Name: chb10_06.edf File Start Time: 03:54:15 File End Time: 5:54:15 Number of Seizures in File: 0
# EDF_CONTAINER: ts_start -2208978345000.0
# EDF_CONTAINER: sz_info []
# EDF_CONTAINER: info_string passed File Name: chb10_07.edf File Start Time: 05:54:23 File End Time: 7:54:23 Number of Seizures in File: 0
# EDF_CONTAINER: ts_start -2208971137000.0
# EDF_CONTAINER: sz_info []
# EDF_CONTAINER: info_string passed File Name: chb10_08.edf File Start Time: 07:54:30 File End Time: 9:54:30 Number of Seizures in File: 0
# EDF_CONTAINER: ts_start -2208963930000.0
# EDF_CONTAINER: sz_info []
# EDF_CONTAINER: info_string passed File Name: chb10_12.edf File Start Time: 15:55:00 File End Time: 17:55:00 Number of Seizures in File: 1 Seizure 1 Start Time: 6313 seconds Seizure 1 End Time: 6348 seconds
# EDF_CONTAINER: ts_start -2208935100000.0
# EDF_CONTAINER: sz_info [{'sz_start': 6313, 'sz_end': 6348}]
# modtaget string: [{'sz_start': 6313, 'sz_end': 6348}]
# sz_start index = 1616128
# sz_end: 1625088
# filename: chb10_12 classes: Interictal    1603840
# Preictal       230400
# seizure          8960
# Name: class, dtype: int64
# -------------------------------------------------------
# chb10_12
# saved: chb10_12
# EDF_CONTAINER: info_string passed File Name: chb10_13.edf File Start Time: 17:55:08 File End Time: 19:55:08 Number of Seizures in File: 0
# EDF_CONTAINER: ts_start -2208927892000.0
# EDF_CONTAINER: sz_info []
# EDF_CONTAINER: info_string passed File Name: chb10_14.edf File Start Time: 19:55:15 File End Time: 21:55:15 Number of Seizures in File: 0
# EDF_CONTAINER: ts_start -2208920685000.0
# EDF_CONTAINER: sz_info []
# EDF_CONTAINER: info_string passed File Name: chb10_15.edf File Start Time: 21:55:23 File End Time: 23:55:23 Number of Seizures in File: 0
# EDF_CONTAINER: ts_start -2208913477000.0
# EDF_CONTAINER: sz_info []
# EDF_CONTAINER: info_string passed File Name: chb10_16.edf File Start Time: 23:55:30 File End Time: 25:55:30 Number of Seizures in File: 0
# EDF_CONTAINER: ts_start -2208906270000.0
# EDF_CONTAINER: sz_info []
# EDF_CONTAINER: info_string passed File Name: chb10_17.edf File Start Time: 01:55:37 File End Time: 3:55:37 Number of Seizures in File: 0
# EDF_CONTAINER: ts_start -2208985463000.0
# EDF_CONTAINER: sz_info []
# EDF_CONTAINER: info_string passed File Name: chb10_18.edf File Start Time: 03:55:45 File End Time: 5:55:45 Number of Seizures in File: 0
# EDF_CONTAINER: ts_start -2208978255000.0
# EDF_CONTAINER: sz_info []
# EDF_CONTAINER: info_string passed File Name: chb10_19.edf File Start Time: 05:55:52 File End Time: 7:55:52 Number of Seizures in File: 0
# EDF_CONTAINER: ts_start -2208971048000.0
# EDF_CONTAINER: sz_info []
# EDF_CONTAINER: info_string passed File Name: chb10_20.edf File Start Time: 07:56:00 File End Time: 9:56:12 Number of Seizures in File: 1 Seizure 1 Start Time: 6888 seconds Seizure 1 End Time: 6958 seconds
# EDF_CONTAINER: ts_start -2208963840000.0
# EDF_CONTAINER: sz_info [{'sz_start': 6888, 'sz_end': 6958}]
# modtaget string: [{'sz_start': 6888, 'sz_end': 6958}]
# sz_start index = 1763328
# sz_end: 1781248
# filename: chb10_20 classes: Interictal    1597952
# Preictal       230400
# seizure         17920
# Name: class, dtype: int64
# -------------------------------------------------------
# chb10_20
# saved: chb10_20
# EDF_CONTAINER: info_string passed File Name: chb10_21.edf File Start Time: 09:58:35 File End Time: 11:58:35 Number of Seizures in File: 0
# EDF_CONTAINER: ts_start -2208956485000.0
# EDF_CONTAINER: sz_info []
# EDF_CONTAINER: info_string passed File Name: chb10_22.edf File Start Time: 11:58:43 File End Time: 13:58:43 Number of Seizures in File: 0
# EDF_CONTAINER: ts_start -2208949277000.0
# EDF_CONTAINER: sz_info []
# EDF_CONTAINER: info_string passed File Name: chb10_27.edf File Start Time: 22:02:08 File End Time: 24:02:26 Number of Seizures in File: 1 Seizure 1 Start Time: 2382 seconds Seizure 1 End Time: 2447 seconds
# EDF_CONTAINER: ts_start -2208913072000.0
# EDF_CONTAINER: sz_info [{'sz_start': 2382, 'sz_end': 2447}]
# modtaget string: [{'sz_start': 2382, 'sz_end': 2447}]
# sz_start index = 609792
# sz_end: 626432
# filename: chb10_27 classes: Interictal    1600768
# Preictal       230400
# seizure         16640
# Name: class, dtype: int64
# -------------------------------------------------------
# chb10_27
# saved: chb10_27
# EDF_CONTAINER: info_string passed File Name: chb10_28.edf File Start Time: 00:03:04 File End Time: 2:03:04 Number of Seizures in File: 0
# EDF_CONTAINER: ts_start -2208992216000.0
# EDF_CONTAINER: sz_info []
# EDF_CONTAINER: info_string passed File Name: chb10_30.edf File Start Time: 04:03:19 File End Time: 6:03:32 Number of Seizures in File: 1 Seizure 1 Start Time: 3021 seconds Seizure 1 End Time: 3079 seconds
# EDF_CONTAINER: ts_start -2208977801000.0
# EDF_CONTAINER: sz_info [{'sz_start': 3021, 'sz_end': 3079}]
# modtaget string: [{'sz_start': 3021, 'sz_end': 3079}]
# sz_start index = 773376
# sz_end: 788224
# filename: chb10_30 classes: Interictal    1601280
# Preictal       230400
# seizure         14848
# Name: class, dtype: int64
# -------------------------------------------------------
# chb10_30
# saved: chb10_30
# EDF_CONTAINER: info_string passed File Name: chb10_31.edf File Start Time: 06:04:00 File End Time: 8:04:21 Number of Seizures in File: 1 Seizure 1 Start Time: 3801 seconds Seizure 1 End Time: 3877 seconds
# EDF_CONTAINER: ts_start -2208970560000.0
# EDF_CONTAINER: sz_info [{'sz_start': 3801, 'sz_end': 3877}]
# modtaget string: [{'sz_start': 3801, 'sz_end': 3877}]
# sz_start index = 973056
# sz_end: 992512
# filename: chb10_31 classes: Interictal    1598720
# Preictal       230400
# seizure         19456
# Name: class, dtype: int64
# -------------------------------------------------------
# chb10_31
# saved: chb10_31
# EDF_CONTAINER: info_string passed File Name: chb10_38.edf File Start Time: 14:33:05 File End Time: 16:33:05 Number of Seizures in File: 1 Seizure 1 Start Time: 4618 seconds Seizure 1 End Time: 4707 seconds
# EDF_CONTAINER: ts_start -2208940015000.0
# EDF_CONTAINER: sz_info [{'sz_start': 4618, 'sz_end': 4707}]
# modtaget string: [{'sz_start': 4618, 'sz_end': 4707}]
# sz_start index = 1182208
# sz_end: 1204992
# filename: chb10_38 classes: Interictal    1590016
# Preictal       230400
# seizure         22784
# Name: class, dtype: int64
# -------------------------------------------------------
# chb10_38
# saved: chb10_38
# ../Dataset/CHB-MIT/Filtered-chb-mit//chb03
# EDF_CONTAINER: info_string passed File Name: chb03_01.edf File Start Time: 13:23:36 File End Time: 14:23:36 Number of Seizures in File: 1 Seizure Start Time: 362 seconds Seizure End Time: 414 seconds
# EDF_CONTAINER: ts_start -2208944184000.0
# EDF_CONTAINER: sz_info [{'sz_start': 362, 'sz_end': 414}]
# modtaget string: [{'sz_start': 362, 'sz_end': 414}]
# sz_start index = 92672
# sz_end: 105984
# filename: chb03_01 classes: Interictal    815616
# Preictal       92672
# seizure        13312
# Name: class, dtype: int64
# -------------------------------------------------------
# chb03_01
# saved: chb03_01
# EDF_CONTAINER: info_string passed File Name: chb03_02.edf File Start Time: 14:23:39 File End Time: 15:23:39 Number of Seizures in File: 1 Seizure Start Time: 731 seconds Seizure End Time: 796 seconds
# EDF_CONTAINER: ts_start -2208940581000.0
# EDF_CONTAINER: sz_info [{'sz_start': 731, 'sz_end': 796}]
# modtaget string: [{'sz_start': 731, 'sz_end': 796}]
# sz_start index = 187136
# sz_end: 203776
# filename: chb03_02 classes: Interictal    717824
# Preictal      187136
# seizure        16640
# Name: class, dtype: int64
# -------------------------------------------------------
# chb03_02
# saved: chb03_02
# EDF_CONTAINER: info_string passed File Name: chb03_03.edf File Start Time: 15:23:47 File End Time: 16:23:47 Number of Seizures in File: 1 Seizure Start Time: 432 seconds Seizure End Time: 501 seconds
# EDF_CONTAINER: ts_start -2208936973000.0
# EDF_CONTAINER: sz_info [{'sz_start': 432, 'sz_end': 501}]
# modtaget string: [{'sz_start': 432, 'sz_end': 501}]
# sz_start index = 110592
# sz_end: 128256
# filename: chb03_03 classes: Interictal    793344
# Preictal      110592
# seizure        17664
# Name: class, dtype: int64
# -------------------------------------------------------
# chb03_03
# saved: chb03_03
# EDF_CONTAINER: info_string passed File Name: chb03_04.edf File Start Time: 16:23:54 File End Time: 17:23:54 Number of Seizures in File: 1 Seizure Start Time: 2162 seconds Seizure End Time: 2214 seconds
# EDF_CONTAINER: ts_start -2208933366000.0
# EDF_CONTAINER: sz_info [{'sz_start': 2162, 'sz_end': 2214}]
# modtaget string: [{'sz_start': 2162, 'sz_end': 2214}]
# sz_start index = 553472
# sz_end: 566784
# filename: chb03_04 classes: Interictal    677888
# Preictal      230400
# seizure        13312
# Name: class, dtype: int64
# -------------------------------------------------------
# chb03_04
# saved: chb03_04
# EDF_CONTAINER: info_string passed File Name: chb03_05.edf File Start Time: 17:24:01 File End Time: 18:24:01 Number of Seizures in File: 0
# EDF_CONTAINER: ts_start -2208929759000.0
# EDF_CONTAINER: sz_info []
# EDF_CONTAINER: info_string passed File Name: chb03_06.edf File Start Time: 18:24:08 File End Time: 19:24:08 Number of Seizures in File: 0
# EDF_CONTAINER: ts_start -2208926152000.0
# EDF_CONTAINER: sz_info []
# EDF_CONTAINER: info_string passed File Name: chb03_07.edf File Start Time: 19:24:15 File End Time: 20:24:15 Number of Seizures in File: 0
# EDF_CONTAINER: ts_start -2208922545000.0
# EDF_CONTAINER: sz_info []
# EDF_CONTAINER: info_string passed File Name: chb03_08.edf File Start Time: 20:24:22 File End Time: 21:24:22 Number of Seizures in File: 0
# EDF_CONTAINER: ts_start -2208918938000.0
# EDF_CONTAINER: sz_info []
# EDF_CONTAINER: info_string passed File Name: chb03_09.edf File Start Time: 21:24:30 File End Time: 22:24:30 Number of Seizures in File: 0
# EDF_CONTAINER: ts_start -2208915330000.0
# EDF_CONTAINER: sz_info []
# EDF_CONTAINER: info_string passed File Name: chb03_10.edf File Start Time: 22:24:37 File End Time: 23:24:37 Number of Seizures in File: 0
# EDF_CONTAINER: ts_start -2208911723000.0
# EDF_CONTAINER: sz_info []
# EDF_CONTAINER: info_string passed File Name: chb03_11.edf File Start Time: 23:24:44 File End Time: 24:24:44 Number of Seizures in File: 0
# EDF_CONTAINER: ts_start -2208908116000.0
# EDF_CONTAINER: sz_info []
# EDF_CONTAINER: info_string passed File Name: chb03_12.edf File Start Time: 00:24:51 File End Time: 1:24:51 Number of Seizures in File: 0
# EDF_CONTAINER: ts_start -2208990909000.0
# EDF_CONTAINER: sz_info []
# EDF_CONTAINER: info_string passed File Name: chb03_13.edf File Start Time: 01:24:59 File End Time: 2:24:59 Number of Seizures in File: 0
# EDF_CONTAINER: ts_start -2208987301000.0
# EDF_CONTAINER: sz_info []
# EDF_CONTAINER: info_string passed File Name: chb03_14.edf File Start Time: 02:25:06 File End Time: 3:25:06 Number of Seizures in File: 0
# EDF_CONTAINER: ts_start -2208983694000.0
# EDF_CONTAINER: sz_info []
# EDF_CONTAINER: info_string passed File Name: chb03_15.edf File Start Time: 03:25:13 File End Time: 4:25:13 Number of Seizures in File: 0
# EDF_CONTAINER: ts_start -2208980087000.0
# EDF_CONTAINER: sz_info []
# EDF_CONTAINER: info_string passed File Name: chb03_16.edf File Start Time: 04:25:20 File End Time: 5:25:20 Number of Seizures in File: 0
# EDF_CONTAINER: ts_start -2208976480000.0
# ...
# EDF_CONTAINER: ts_start -2208988595000.0
# EDF_CONTAINER: sz_info []
# EDF_CONTAINER: info_string passed File Name: chb22_54.edf File Start Time: 04:03:46 File End Time: 5:03:46 Number of Seizures in File: 0
# EDF_CONTAINER: ts_start -2208977774000.0
# EDF_CONTAINER: sz_info []
# ../Dataset/CHB-MIT/Filtered-chb-mit//chb07
# EDF_CONTAINER: info_string passed File Name: chb07_01.edf File Start Time: 16:58:28 File End Time: 20:58:39 Number of Seizures in File: 0
# EDF_CONTAINER: ts_start -2208931292000.0
# EDF_CONTAINER: sz_info []
# EDF_CONTAINER: info_string passed File Name: chb07_02.edf File Start Time: 21:00:13 File End Time: 25:00:13 Number of Seizures in File: 0
# EDF_CONTAINER: ts_start -2208916787000.0
# EDF_CONTAINER: sz_info []
# EDF_CONTAINER: info_string passed File Name: chb07_03.edf File Start Time: 01:00:21 File End Time: 5:00:21 Number of Seizures in File: 0
# EDF_CONTAINER: ts_start -2208988779000.0
# EDF_CONTAINER: sz_info []
# EDF_CONTAINER: info_string passed File Name: chb07_04.edf File Start Time: 05:00:29 File End Time: 9:00:29 Number of Seizures in File: 0
# EDF_CONTAINER: ts_start -2208974371000.0
# EDF_CONTAINER: sz_info []
# EDF_CONTAINER: info_string passed File Name: chb07_05.edf File Start Time: 09:00:36 File End Time: 13:00:36 Number of Seizures in File: 0
# EDF_CONTAINER: ts_start -2208959964000.0
# EDF_CONTAINER: sz_info []
# EDF_CONTAINER: info_string passed File Name: chb07_06.edf File Start Time: 13:00:44 File End Time: 14:22:44 Number of Seizures in File: 0
# EDF_CONTAINER: ts_start -2208945556000.0
# EDF_CONTAINER: sz_info []
# EDF_CONTAINER: info_string passed File Name: chb07_07.edf File Start Time: 14:23:26 File End Time: 15:41:06 Number of Seizures in File: 0
# EDF_CONTAINER: ts_start -2208940594000.0
# EDF_CONTAINER: sz_info []
# EDF_CONTAINER: info_string passed File Name: chb07_08.edf File Start Time: 15:45:54 File End Time: 19:45:54 Number of Seizures in File: 0
# EDF_CONTAINER: ts_start -2208935646000.0
# EDF_CONTAINER: sz_info []
# EDF_CONTAINER: info_string passed File Name: chb07_09.edf File Start Time: 19:45:58 File End Time: 23:45:58 Number of Seizures in File: 0
# EDF_CONTAINER: ts_start -2208921242000.0
# EDF_CONTAINER: sz_info []
# EDF_CONTAINER: info_string passed File Name: chb07_10.edf File Start Time: 23:46:06 File End Time: 27:46:06 Number of Seizures in File: 0
# EDF_CONTAINER: ts_start -2208906834000.0
# EDF_CONTAINER: sz_info []
# EDF_CONTAINER: info_string passed File Name: chb07_11.edf File Start Time: 03:46:13 File End Time: 7:46:13 Number of Seizures in File: 0
# EDF_CONTAINER: ts_start -2208978827000.0
# EDF_CONTAINER: sz_info []
# EDF_CONTAINER: info_string passed File Name: chb07_12.edf File Start Time: 07:46:22 File End Time: 11:46:22 Number of Seizures in File: 1 Seizure 1 Start Time: 4920 seconds Seizure 1 End Time: 5006 seconds
# EDF_CONTAINER: ts_start -2208964418000.0
# EDF_CONTAINER: sz_info [{'sz_start': 4920, 'sz_end': 5006}]
# modtaget string: [{'sz_start': 4920, 'sz_end': 5006}]
# sz_start index = 1259520
# sz_end: 1281536
# filename: chb07_12 classes: Interictal    3433984
# Preictal       230400
# seizure         22016
# Name: class, dtype: int64
# -------------------------------------------------------
# chb07_12
# saved: chb07_12
# EDF_CONTAINER: info_string passed File Name: chb07_13.edf File Start Time: 11:46:29 File End Time: 12:48:35 Number of Seizures in File: 1 Seizure 1 Start Time: 3285 seconds Seizure 1 End Time: 3381 seconds
# EDF_CONTAINER: ts_start -2208950011000.0
# EDF_CONTAINER: sz_info [{'sz_start': 3285, 'sz_end': 3381}]
# modtaget string: [{'sz_start': 3285, 'sz_end': 3381}]
# sz_start index = 840960
# sz_end: 865536
# filename: chb07_13 classes: Interictal    698880
# Preictal      230400
# seizure        24576
# Name: class, dtype: int64
# -------------------------------------------------------
# chb07_13
# saved: chb07_13
# EDF_CONTAINER: info_string passed File Name: chb07_14.edf File Start Time: 12:48:54 File End Time: 16:48:54 Number of Seizures in File: 0
# EDF_CONTAINER: ts_start -2208946266000.0
# EDF_CONTAINER: sz_info []
# EDF_CONTAINER: info_string passed File Name: chb07_15.edf File Start Time: 16:48:58 File End Time: 20:48:58 Number of Seizures in File: 0
# EDF_CONTAINER: ts_start -2208931862000.0
# EDF_CONTAINER: sz_info []
# EDF_CONTAINER: info_string passed File Name: chb07_16.edf File Start Time: 20:49:06 File End Time: 24:49:06 Number of Seizures in File: 0
# EDF_CONTAINER: ts_start -2208917454000.0
# EDF_CONTAINER: sz_info []
# EDF_CONTAINER: info_string passed File Name: chb07_17.edf File Start Time: 00:49:19 File End Time: 4:49:19 Number of Seizures in File: 0
# EDF_CONTAINER: ts_start -2208989441000.0
# EDF_CONTAINER: sz_info []
# EDF_CONTAINER: info_string passed File Name: chb07_18.edf File Start Time: 04:49:28 File End Time: 8:10:28 Number of Seizures in File: 0
# EDF_CONTAINER: ts_start -2208975032000.0
# EDF_CONTAINER: sz_info []
# ../Dataset/CHB-MIT/Filtered-chb-mit//chb01
# EDF_CONTAINER: info_string passed File Name: chb01_01.edf File Start Time: 11:42:54 File End Time: 12:42:54 Number of Seizures in File: 0
# EDF_CONTAINER: ts_start -2208950226000.0
# EDF_CONTAINER: sz_info []
# EDF_CONTAINER: info_string passed File Name: chb01_02.edf File Start Time: 12:42:57 File End Time: 13:42:57 Number of Seizures in File: 0
# EDF_CONTAINER: ts_start -2208946623000.0
# EDF_CONTAINER: sz_info []
# EDF_CONTAINER: info_string passed File Name: chb01_03.edf File Start Time: 13:43:04 File End Time: 14:43:04 Number of Seizures in File: 1 Seizure Start Time: 2996 seconds Seizure End Time: 3036 seconds
# EDF_CONTAINER: ts_start -2208943016000.0
# EDF_CONTAINER: sz_info [{'sz_start': 2996, 'sz_end': 3036}]
# modtaget string: [{'sz_start': 2996, 'sz_end': 3036}]
# sz_start index = 766976
# sz_end: 777216
# filename: chb01_03 classes: Interictal    680960
# Preictal      230400
# seizure        10240
# Name: class, dtype: int64
# -------------------------------------------------------
# chb01_03
# saved: chb01_03
# EDF_CONTAINER: info_string passed File Name: chb01_04.edf File Start Time: 14:43:12 File End Time: 15:43:12 Number of Seizures in File: 1 Seizure Start Time: 1467 seconds Seizure End Time: 1494 seconds
# EDF_CONTAINER: ts_start -2208939408000.0
# EDF_CONTAINER: sz_info [{'sz_start': 1467, 'sz_end': 1494}]
# modtaget string: [{'sz_start': 1467, 'sz_end': 1494}]
# sz_start index = 375552
# sz_end: 382464
# filename: chb01_04 classes: Interictal    684288
# Preictal      230400
# seizure         6912
# Name: class, dtype: int64
# -------------------------------------------------------
# chb01_04
# saved: chb01_04
# EDF_CONTAINER: info_string passed File Name: chb01_05.edf File Start Time: 15:43:19 File End Time: 16:43:19 Number of Seizures in File: 0
# EDF_CONTAINER: ts_start -2208935801000.0
# EDF_CONTAINER: sz_info []
# EDF_CONTAINER: info_string passed File Name: chb01_06.edf File Start Time: 16:43:26 File End Time: 17:43:26 Number of Seizures in File: 0
# EDF_CONTAINER: ts_start -2208932194000.0
# EDF_CONTAINER: sz_info []
# EDF_CONTAINER: info_string passed File Name: chb01_07.edf File Start Time: 17:43:33 File End Time: 18:43:33 Number of Seizures in File: 0
# EDF_CONTAINER: ts_start -2208928587000.0
# EDF_CONTAINER: sz_info []
# EDF_CONTAINER: info_string passed File Name: chb01_08.edf File Start Time: 18:43:40 File End Time: 19:43:40 Number of Seizures in File: 0
# EDF_CONTAINER: ts_start -2208924980000.0
# EDF_CONTAINER: sz_info []
# EDF_CONTAINER: info_string passed File Name: chb01_09.edf File Start Time: 19:43:56 File End Time: 20:43:56 Number of Seizures in File: 0
# EDF_CONTAINER: ts_start -2208921364000.0
# EDF_CONTAINER: sz_info []
# EDF_CONTAINER: info_string passed File Name: chb01_10.edf File Start Time: 20:44:07 File End Time: 21:44:07 Number of Seizures in File: 0
# EDF_CONTAINER: ts_start -2208917753000.0
# EDF_CONTAINER: sz_info []
# EDF_CONTAINER: info_string passed File Name: chb01_11.edf File Start Time: 21:44:14 File End Time: 22:44:14 Number of Seizures in File: 0
# EDF_CONTAINER: ts_start -2208914146000.0
# EDF_CONTAINER: sz_info []
# EDF_CONTAINER: info_string passed File Name: chb01_12.edf File Start Time: 22:44:22 File End Time: 23:44:22 Number of Seizures in File: 0
# EDF_CONTAINER: ts_start -2208910538000.0
# EDF_CONTAINER: sz_info []
# EDF_CONTAINER: info_string passed File Name: chb01_13.edf File Start Time: 23:44:29 File End Time: 24:44:29 Number of Seizures in File: 0
# EDF_CONTAINER: ts_start -2208906931000.0
# EDF_CONTAINER: sz_info []
# EDF_CONTAINER: info_string passed File Name: chb01_14.edf File Start Time: 00:44:37 File End Time: 1:44:37 Number of Seizures in File: 0
# EDF_CONTAINER: ts_start -2208989723000.0
# EDF_CONTAINER: sz_info []
# EDF_CONTAINER: info_string passed File Name: chb01_15.edf File Start Time: 01:44:44 File End Time: 2:44:44 Number of Seizures in File: 1 Seizure Start Time: 1732 seconds Seizure End Time: 1772 seconds
# EDF_CONTAINER: ts_start -2208986116000.0
# EDF_CONTAINER: sz_info [{'sz_start': 1732, 'sz_end': 1772}]
# modtaget string: [{'sz_start': 1732, 'sz_end': 1772}]
# sz_start index = 443392
# sz_end: 453632
# filename: chb01_15 classes: Interictal    680960
# Preictal      230400
# seizure        10240
# Name: class, dtype: int64
# -------------------------------------------------------
# chb01_15
# saved: chb01_15
# EDF_CONTAINER: info_string passed File Name: chb01_16.edf File Start Time: 02:44:51 File End Time: 3:44:51 Number of Seizures in File: 1 Seizure Start Time: 1015 seconds Seizure End Time: 1066 seconds
# EDF_CONTAINER: ts_start -2208982509000.0
# EDF_CONTAINER: sz_info [{'sz_start': 1015, 'sz_end': 1066}]
# modtaget string: [{'sz_start': 1015, 'sz_end': 1066}]
# sz_start index = 259840
# sz_end: 272896
# filename: chb01_16 classes: Interictal    678144
# Preictal      230400
# seizure        13056
# Name: class, dtype: int64
# -------------------------------------------------------
# chb01_16
# saved: chb01_16
# EDF_CONTAINER: info_string passed File Name: chb01_17.edf File Start Time: 03:44:59 File End Time: 4:44:59 Number of Seizures in File: 0
# EDF_CONTAINER: ts_start -2208978901000.0
# EDF_CONTAINER: sz_info []
# EDF_CONTAINER: info_string passed File Name: chb01_18.edf File Start Time: 04:45:06 File End Time: 5:45:06 Number of Seizures in File: 1 Seizure Start Time: 1720 seconds Seizure End Time: 1810 seconds
# EDF_CONTAINER: ts_start -2208975294000.0
# EDF_CONTAINER: sz_info [{'sz_start': 1720, 'sz_end': 1810}]
# modtaget string: [{'sz_start': 1720, 'sz_end': 1810}]
# sz_start index = 440320
# sz_end: 463360
# filename: chb01_18 classes: Interictal    668160
# Preictal      230400
# seizure        23040
# Name: class, dtype: int64
# -------------------------------------------------------
# chb01_18
# saved: chb01_18
# EDF_CONTAINER: info_string passed File Name: chb01_19.edf File Start Time: 05:45:13 File End Time: 6:45:13 Number of Seizures in File: 0
# EDF_CONTAINER: ts_start -2208971687000.0
# EDF_CONTAINER: sz_info []
# EDF_CONTAINER: info_string passed File Name: chb01_20.edf File Start Time: 06:45:20 File End Time: 7:29:43 Number of Seizures in File: 0
# EDF_CONTAINER: ts_start -2208968080000.0
# EDF_CONTAINER: sz_info []
# EDF_CONTAINER: info_string passed File Name: chb01_21.edf File Start Time: 07:33:46 File End Time: 8:33:46 Number of Seizures in File: 1 Seizure Start Time: 327 seconds Seizure End Time: 420 seconds
# EDF_CONTAINER: ts_start -2208965174000.0
# EDF_CONTAINER: sz_info [{'sz_start': 327, 'sz_end': 420}]
# modtaget string: [{'sz_start': 327, 'sz_end': 420}]
# sz_start index = 83712
# sz_end: 107520
# filename: chb01_21 classes: Interictal    814080
# Preictal       83712
# seizure        23808
# Name: class, dtype: int64
# -------------------------------------------------------
# chb01_21
# saved: chb01_21
# EDF_CONTAINER: info_string passed File Name: chb01_22.edf File Start Time: 08:33:49 File End Time: 9:33:49 Number of Seizures in File: 0
# EDF_CONTAINER: ts_start -2208961571000.0
# EDF_CONTAINER: sz_info []
# EDF_CONTAINER: info_string passed File Name: chb01_23.edf File Start Time: 09:33:58 File End Time: 10:33:58 Number of Seizures in File: 0
# EDF_CONTAINER: ts_start -2208957962000.0
# EDF_CONTAINER: sz_info []
# EDF_CONTAINER: info_string passed File Name: chb01_24.edf File Start Time: 10:34:06 File End Time: 11:34:06 Number of Seizures in File: 0
# EDF_CONTAINER: ts_start -2208954354000.0
# EDF_CONTAINER: sz_info []
# EDF_CONTAINER: info_string passed File Name: chb01_25.edf File Start Time: 11:34:14 File End Time: 12:34:14 Number of Seizures in File: 0
# EDF_CONTAINER: ts_start -2208950746000.0
# EDF_CONTAINER: sz_info []
# EDF_CONTAINER: info_string passed File Name: chb01_26.edf File Start Time: 12:34:22 File End Time: 13:13:07 Number of Seizures in File: 1 Seizure Start Time: 1862 seconds Seizure End Time: 1963 seconds
# EDF_CONTAINER: ts_start -2208947138000.0
# EDF_CONTAINER: sz_info [{'sz_start': 1862, 'sz_end': 1963}]
# modtaget string: [{'sz_start': 1862, 'sz_end': 1963}]
# sz_start index = 476672
# sz_end: 502528
# filename: chb01_26 classes: Interictal    338944
# Preictal      230400
# seizure        25856
# Name: class, dtype: int64
# -------------------------------------------------------
# chb01_26
# saved: chb01_26
# EDF_CONTAINER: info_string passed File Name: chb01_27.edf File Start Time: 13:13:21 File End Time: 13:23:21 Number of Seizures in File: 0
# EDF_CONTAINER: ts_start -2208944799000.0
# EDF_CONTAINER: sz_info []
# EDF_CONTAINER: info_string passed File Name: chb01_29.edf File Start Time: 13:24:08 File End Time: 14:24:08 Number of Seizures in File: 0
# EDF_CONTAINER: ts_start -2208944152000.0
# EDF_CONTAINER: sz_info []
# EDF_CONTAINER: info_string passed File Name: chb01_30.edf File Start Time: 14:24:15 File End Time: 15:24:15 Number of Seizures in File: 0
# EDF_CONTAINER: ts_start -2208940545000.0
# EDF_CONTAINER: sz_info []
# EDF_CONTAINER: info_string passed File Name: chb01_31.edf File Start Time: 15:24:24 File End Time: 16:24:24 Number of Seizures in File: 0
# EDF_CONTAINER: ts_start -2208936936000.0
# EDF_CONTAINER: sz_info []
# EDF_CONTAINER: info_string passed File Name: chb01_32.edf File Start Time: 16:24:32 File End Time: 17:24:32 Number of Seizures in File: 0
# EDF_CONTAINER: ts_start -2208933328000.0
# EDF_CONTAINER: sz_info []
# EDF_CONTAINER: info_string passed File Name: chb01_33.edf File Start Time: 17:24:39 File End Time: 18:24:39 Number of Seizures in File: 0
# EDF_CONTAINER: ts_start -2208929721000.0
# EDF_CONTAINER: sz_info []
# EDF_CONTAINER: info_string passed File Name: chb01_34.edf File Start Time: 18:24:46 File End Time: 19:24:46 Number of Seizures in File: 0
# EDF_CONTAINER: ts_start -2208926114000.0
# EDF_CONTAINER: sz_info []
# EDF_CONTAINER: info_string passed File Name: chb01_36.edf File Start Time: 22:14:43 File End Time: 23:14:43 Number of Seizures in File: 0
# EDF_CONTAINER: ts_start -2208912317000.0
# EDF_CONTAINER: sz_info []
# EDF_CONTAINER: info_string passed File Name: chb01_37.edf File Start Time: 23:14:46 File End Time: 24:14:46 Number of Seizures in File: 0
# EDF_CONTAINER: ts_start -2208908714000.0
# EDF_CONTAINER: sz_info []
# EDF_CONTAINER: info_string passed File Name: chb01_38.edf File Start Time: 00:14:53 File End Time: 1:14:53 Number of Seizures in File: 0
# EDF_CONTAINER: ts_start -2208991507000.0
# EDF_CONTAINER: sz_info []
# EDF_CONTAINER: info_string passed File Name: chb01_39.edf File Start Time: 01:15:01 File End Time: 2:15:01 Number of Seizures in File: 0
# EDF_CONTAINER: ts_start -2208987899000.0
# EDF_CONTAINER: sz_info []
# EDF_CONTAINER: info_string passed File Name: chb01_40.edf File Start Time: 02:15:08 File End Time: 3:15:08 Number of Seizures in File: 0
# EDF_CONTAINER: ts_start -2208984292000.0
# EDF_CONTAINER: sz_info []
# EDF_CONTAINER: info_string passed File Name: chb01_41.edf File Start Time: 03:15:15 File End Time: 4:15:15 Number of Seizures in File: 0
# EDF_CONTAINER: ts_start -2208980685000.0
# EDF_CONTAINER: sz_info []
# EDF_CONTAINER: info_string passed File Name: chb01_42.edf File Start Time: 04:15:22 File End Time: 5:15:22 Number of Seizures in File: 0
# EDF_CONTAINER: ts_start -2208977078000.0
# EDF_CONTAINER: sz_info []
# EDF_CONTAINER: info_string passed File Name: chb01_43.edf File Start Time: 05:15:29 File End Time: 6:15:29 Number of Seizures in File: 0
# EDF_CONTAINER: ts_start -2208973471000.0
# EDF_CONTAINER: sz_info []

# %%
x = ReadEdfFile("../Dataset/CHB-MIT/Filtered-chb-mit//chb20//chb20_13.edf")
x2 = downcast_dtypes(x)
info_txt = read_format_info_file("../Dataset/CHB-MIT/Filtered-chb-mit//chb20//chb20-summary.txt")[11:12]
print(info_txt)
ex_con = FileInformationContainer(info_txt[0])
print("INFORMATION: " + ex_con.information_str)
print(ex_con.get_sz_count())
insert_time_stamp(x, ex_con.time_start)
print(f"info list = {ex_con.sz_info}")
insert_class_col(x, ex_con.sz_info)


x.isna().sum()
